# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # Implement Min-Max for RGB [0,255]
    min_interval = 0
    max_interval = 1
    colorscale_min = 0
    colorscale_max = 255
    return  min_interval + (((x - colorscale_min)*(max_interval - min_interval))/(colorscale_max - colorscale_min))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing

# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html
lb = preprocessing.LabelBinarizer()
lb.fit(range(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    batch = None
    size = [batch,image_shape[0],image_shape[1],image_shape[2]] # H x W x D

    return tf.placeholder(tf.float32,shape=size,name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    batch = None
    size = [batch,n_classes]
    return tf.placeholder(tf.float32,shape=size,name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    # Output depth
    k_output = conv_num_outputs
    
    # Weight and bias
    ## Image Properties
    # batch_size = x_tensor.get_shape().as_list()[0]
    # image_width = x_tensor.get_shape().as_list()[1]
    # image_height = x_tensor.get_shape().as_list()[2]
    color_channels = x_tensor.get_shape().as_list()[3]

    # Convolution filter
    filter_size_width = conv_ksize[0]
    filter_size_height = conv_ksize[1]
    
    # Weight and bias
    # (height, width , deth_input, deth_output)
    weights = tf.Variable(tf.truncated_normal([filter_size_height, filter_size_width, color_channels, k_output],stddev=0.1)) 
    bias = tf.Variable(tf.zeros(k_output))
     
    
    # Apply Convolution
    # (batch, height, width , deth)
    conv_strides = [1, conv_strides[0], conv_strides[1], 1]
    conv_layer = tf.nn.conv2d(input=x_tensor, filter=weights, strides=conv_strides, padding='SAME')
    
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    # Apply activation function
    conv_layer = tf.nn.relu(conv_layer)
    
    # Create ksize 
    pool_ksize = (1, pool_ksize[0], pool_ksize[1], 1)
    
    # Create strides
    pool_strides=(1,pool_strides[0], pool_strides[1], 1)
    
    # Apply max-pooling
    conv_layer = tf.nn.max_pool(conv_layer, ksize=pool_ksize, strides=pool_strides, padding='SAME')
    
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    x_list = x_tensor.get_shape().as_list()
    batch_size = x_list[0]
    image_width = x_list[1]
    image_height = x_list[2]
    depth = x_list[3]
    
    flattened = int(image_height * image_width * depth)
    
    return tf.reshape(x_tensor, [-1, flattened])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    tensor_shape = x_tensor.get_shape().as_list()
    batch_size = tensor_shape[0]
    num_features = tensor_shape[1] # num_in
    
    #weights = tf.get_variable('weights',
    #                           shape=[num_features, num_outputs],
    #                           initializer=tf.random_normal_initializer(stddev=0.1))    
    # OR bias = tf.get_variable('bias',
    #                          shape=[num_outputs],
    #                          initializer=tf.constant_initializer(0.0))
    weights = tf.Variable(tf.random_normal([num_features, num_outputs],stddev=0.1))
    
    bias = tf.Variable(tf.zeros(num_outputs))
    
    # Multiply input by weights and add bias
    fully_conn = tf.matmul(x_tensor, weights)
    fully_conn = tf.nn.bias_add(fully_conn, bias)
    
     # Apply activation function
    fully_conn = tf.nn.relu(fully_conn)
    
    return fully_conn

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    tensor_shape = x_tensor.get_shape().as_list()
    batch_size = tensor_shape[0]
    num_features = tensor_shape[1] # num_in = x_tensor.get_shape().as_list()[1]
    

    weights = tf.Variable(tf.random_normal([num_features, num_outputs],stddev=0.1))
    
    bias = tf.Variable(tf.zeros(num_outputs))
    
    # weights = tf.get_variable('weights',
    #                          shape=[num_features, num_outputs],
    #                          initializer=tf.random_normal_initializer(stddev=0.1))
        
    # Or bias = tf.get_variable('biases',
    #                          shape=[num_outputs],
    #                          initializer=tf.constant_initializer(0.0))
    
    # Multiply input by weights and add bias
    output = tf.add(tf.matmul(x_tensor, weights), bias)
    
    return output       

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # Variable initialization
    conv_ksize = (5, 5)
    conv_strides = (1, 1)
    pool_ksize = (3, 3)
    pool_strides = (2, 2)
       
    # layer 1 - 32x32x3 to 16x16x32
    conv_layer = conv2d_maxpool(x, 
                                conv_num_outputs=32, 
                                conv_ksize=conv_ksize, 
                                conv_strides=conv_strides, 
                                pool_ksize=pool_ksize, 
                                pool_strides=pool_strides)
    
    # layer 2 - 16x16x32 to 8x8x64
    conv_layer = conv2d_maxpool(conv_layer, 
                                conv_num_outputs=64, 
                                conv_ksize=conv_ksize, 
                                conv_strides=conv_strides, 
                                pool_ksize=pool_ksize, 
                                pool_strides=pool_strides)
    
    # layer 3 - 8x8x64 o 4x4x128
    conv_layer = conv2d_maxpool(conv_layer, 
                                conv_num_outputs=128, 
                                conv_ksize=conv_ksize, 
                                conv_strides=conv_strides, 
                                pool_ksize=pool_ksize, 
                                pool_strides=pool_strides)
    
    # layer 4 - 4x4x384 to 2x2x512
    # conv_layer = conv2d_maxpool(conv_layer, 512, (2, 2), (2, 2), (1, 1), (1, 1))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    conv_layer = flatten(conv_layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    # Fully connected layer 1 - to 512
    fully_conn_layer = fully_conn(conv_layer, 512)
    
    # Dropout
    fully_conn_layer = tf.nn.dropout(fully_conn_layer, keep_prob)
    
    # Fully connected layer 2 - 512 to 64
    fully_conn_layer = fully_conn(fully_conn_layer, 64)
    
    # Dropout
    fully_conn_layer = tf.nn.dropout(fully_conn_layer, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    # Output layer -- 128 to 10
    out = output(fully_conn_layer, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    
    session.run(optimizer, feed_dict={
        x: feature_batch, 
        y: label_batch, 
        keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
    x: feature_batch, 
    y: label_batch,
    keep_prob: 1.0})
    
    valid_accuracy = session.run(accuracy, feed_dict={
    x: valid_features,
    y: valid_labels,
    keep_prob: 1.0})
        
    print('Loss: {:>10.4f} | Validation Accuracy: {:.4f}'.format(
        loss,
        valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2415 | Validation Accuracy: 0.2168
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.0311 | Validation Accuracy: 0.3198
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.8692 | Validation Accuracy: 0.3532
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6767 | Validation Accuracy: 0.4178
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5218 | Validation Accuracy: 0.4396
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4354 | Validation Accuracy: 0.4406
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.2376 | Validation Accuracy: 0.4890
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.0675 | Validation Accuracy: 0.5106
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.0048 | Validation Accuracy: 0.5260
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.8027 | Validation Accuracy: 0.5302
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.7280 | Validation Accuracy: 0.5422
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.7216 | Validation Accuracy: 0.5522
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.5943 | Validation Accuracy: 0.5440
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.5998 | Validation Accuracy: 0.5618
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.5215 | Validation Accuracy: 0.5784
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.4206 | Validation Accuracy: 0.5674
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.3880 | Validation Accuracy: 0.5582
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.2760 | Validation Accuracy: 0.5684
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.2595 | Validation Accuracy: 0.5772
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.2676 | Validation Accuracy: 0.5554
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.1905 | Validation Accuracy: 0.5952
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.1585 | Validation Accuracy: 0.5594
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.1363 | Validation Accuracy: 0.6008
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0999 | Validation Accuracy: 0.5934
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.1078 | Validation Accuracy: 0.5942
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.1035 | Validation Accuracy: 0.5794
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0679 | Validation Accuracy: 0.6016
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0977 | Validation Accuracy: 0.5964
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0527 | Validation Accuracy: 0.5858
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0472 | Validation Accuracy: 0.5938
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0742 | Validation Accuracy: 0.5808
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0377 | Validation Accuracy: 0.5862
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0348 | Validation Accuracy: 0.5808
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0350 | Validation Accuracy: 0.5876
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0154 | Validation Accuracy: 0.5940
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0448 | Validation Accuracy: 0.5790
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0122 | Validation Accuracy: 0.6026
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0085 | Validation Accuracy: 0.5854
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0014 | Validation Accuracy: 0.6036
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0060 | Validation Accuracy: 0.5818
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0019 | Validation Accuracy: 0.6026
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0032 | Validation Accuracy: 0.6024
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0131 | Validation Accuracy: 0.5916
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0065 | Validation Accuracy: 0.5736
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0026 | Validation Accuracy: 0.5920
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0011 | Validation Accuracy: 0.5930
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0022 | Validation Accuracy: 0.5948
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0019 | Validation Accuracy: 0.6044
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0162 | Validation Accuracy: 0.5946
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0037 | Validation Accuracy: 0.5950
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0004 | Validation Accuracy: 0.5896
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0016 | Validation Accuracy: 0.6074
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.1033 | Validation Accuracy: 0.5968
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0054 | Validation Accuracy: 0.6008
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0008 | Validation Accuracy: 0.5962
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.6130
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0044 | Validation Accuracy: 0.5884
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0012 | Validation Accuracy: 0.6104
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0005 | Validation Accuracy: 0.6054
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0006 | Validation Accuracy: 0.6028
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0009 | Validation Accuracy: 0.5928
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0020 | Validation Accuracy: 0.5862
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0011 | Validation Accuracy: 0.6048
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0040 | Validation Accuracy: 0.6056
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0004 | Validation Accuracy: 0.5998
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.5892
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5966
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0006 | Validation Accuracy: 0.5870
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0009 | Validation Accuracy: 0.6018
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.6082
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0026 | Validation Accuracy: 0.6096
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0003 | Validation Accuracy: 0.5862
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0007 | Validation Accuracy: 0.5878
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0010 | Validation Accuracy: 0.5858
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0003 | Validation Accuracy: 0.5920
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0004 | Validation Accuracy: 0.5880
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0003 | Validation Accuracy: 0.5970
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.6012
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0013 | Validation Accuracy: 0.5850
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.6106
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.5948
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.5892
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0004 | Validation Accuracy: 0.5960
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.5926
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.5944
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0004 | Validation Accuracy: 0.5974
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.5924
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5984
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0081 | Validation Accuracy: 0.5936
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.5956
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0016 | Validation Accuracy: 0.6046
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0234 | Validation Accuracy: 0.5742
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6012
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6026
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6012
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6014
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6078
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6008
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.5898

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2504 | Validation Accuracy: 0.1620
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.9648 | Validation Accuracy: 0.3150
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.6403 | Validation Accuracy: 0.3916
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.6513 | Validation Accuracy: 0.4010
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.5555 | Validation Accuracy: 0.4372
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.6624 | Validation Accuracy: 0.4494
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.4632 | Validation Accuracy: 0.4356
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.2223 | Validation Accuracy: 0.4844
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.3812 | Validation Accuracy: 0.4778
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.3671 | Validation Accuracy: 0.5206
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.2791 | Validation Accuracy: 0.5276
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.2135 | Validation Accuracy: 0.5112
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.0308 | Validation Accuracy: 0.5388
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.1651 | Validation Accuracy: 0.5656
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.1547 | Validation Accuracy: 0.5660
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.0770 | Validation Accuracy: 0.5896
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.0285 | Validation Accuracy: 0.5868
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.7704 | Validation Accuracy: 0.5988
# Epoch  4, CIFAR-10 Batch 4:  Loss:     0.8430 | Validation Accuracy: 0.5976
# Epoch  4, CIFAR-10 Batch 5:  Loss:     0.9397 | Validation Accuracy: 0.6156
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.9637 | Validation Accuracy: 0.6094
# Epoch  5, CIFAR-10 Batch 2:  Loss:     0.8506 | Validation Accuracy: 0.5828
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.6498 | Validation Accuracy: 0.6242
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.7547 | Validation Accuracy: 0.6166
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.7350 | Validation Accuracy: 0.6426
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.8030 | Validation Accuracy: 0.6496
# Epoch  6, CIFAR-10 Batch 2:  Loss:     0.6282 | Validation Accuracy: 0.6318
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.5174 | Validation Accuracy: 0.6328
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.6680 | Validation Accuracy: 0.6492
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.6845 | Validation Accuracy: 0.6344
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.7406 | Validation Accuracy: 0.6522
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.6230 | Validation Accuracy: 0.6456
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.4695 | Validation Accuracy: 0.6592
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.5808 | Validation Accuracy: 0.6642
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.5277 | Validation Accuracy: 0.6628
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.5874 | Validation Accuracy: 0.6558
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.4866 | Validation Accuracy: 0.6596
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.3847 | Validation Accuracy: 0.6696
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.4062 | Validation Accuracy: 0.6760
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.3958 | Validation Accuracy: 0.6904
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.4872 | Validation Accuracy: 0.6672
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.4237 | Validation Accuracy: 0.6814
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.3070 | Validation Accuracy: 0.6890
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.4151 | Validation Accuracy: 0.6914
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.3340 | Validation Accuracy: 0.7000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.4611 | Validation Accuracy: 0.6896
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.3657 | Validation Accuracy: 0.7018
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.2695 | Validation Accuracy: 0.7012
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.3361 | Validation Accuracy: 0.6962
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.2742 | Validation Accuracy: 0.6776
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.4312 | Validation Accuracy: 0.6934
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.2620 | Validation Accuracy: 0.7068
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.2087 | Validation Accuracy: 0.7018
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.2715 | Validation Accuracy: 0.7098
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.2318 | Validation Accuracy: 0.7044
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.3256 | Validation Accuracy: 0.7142
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.2006 | Validation Accuracy: 0.7140
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.1509 | Validation Accuracy: 0.7094
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.2210 | Validation Accuracy: 0.7232
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.1951 | Validation Accuracy: 0.7166
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.2709 | Validation Accuracy: 0.7100
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.2167 | Validation Accuracy: 0.7012
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.1242 | Validation Accuracy: 0.7116
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.2121 | Validation Accuracy: 0.7204
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.1343 | Validation Accuracy: 0.7118
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.1979 | Validation Accuracy: 0.7210
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.2062 | Validation Accuracy: 0.7168
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.0711 | Validation Accuracy: 0.7270
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.2158 | Validation Accuracy: 0.7064
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.1308 | Validation Accuracy: 0.7104
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.2229 | Validation Accuracy: 0.7120
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.1715 | Validation Accuracy: 0.7106
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.1005 | Validation Accuracy: 0.7160
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.1652 | Validation Accuracy: 0.7052
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.0848 | Validation Accuracy: 0.7170
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.2006 | Validation Accuracy: 0.7210
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.1768 | Validation Accuracy: 0.7140
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.1138 | Validation Accuracy: 0.6892
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.1821 | Validation Accuracy: 0.7056
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.0646 | Validation Accuracy: 0.7200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.1218 | Validation Accuracy: 0.7226
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.1244 | Validation Accuracy: 0.7228
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.0609 | Validation Accuracy: 0.7036
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.1067 | Validation Accuracy: 0.7114
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.0483 | Validation Accuracy: 0.7166
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.1222 | Validation Accuracy: 0.7196
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.1505 | Validation Accuracy: 0.7290
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.0879 | Validation Accuracy: 0.7100
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.1120 | Validation Accuracy: 0.6974
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.0413 | Validation Accuracy: 0.7198
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0954 | Validation Accuracy: 0.7110
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.1336 | Validation Accuracy: 0.7200
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0238 | Validation Accuracy: 0.7212
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.0981 | Validation Accuracy: 0.6994
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.0457 | Validation Accuracy: 0.7048
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.1032 | Validation Accuracy: 0.7206
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0678 | Validation Accuracy: 0.7098
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0226 | Validation Accuracy: 0.7124
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.0501 | Validation Accuracy: 0.7230
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.0357 | Validation Accuracy: 0.7182
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0872 | Validation Accuracy: 0.7244
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0527 | Validation Accuracy: 0.7152
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0231 | Validation Accuracy: 0.7204
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.0515 | Validation Accuracy: 0.7162
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0357 | Validation Accuracy: 0.7106
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0615 | Validation Accuracy: 0.7180
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0625 | Validation Accuracy: 0.7252
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0146 | Validation Accuracy: 0.7250
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0780 | Validation Accuracy: 0.7032
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0173 | Validation Accuracy: 0.7130
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0581 | Validation Accuracy: 0.7086
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0795 | Validation Accuracy: 0.7264
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0161 | Validation Accuracy: 0.7118
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0811 | Validation Accuracy: 0.7118
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0472 | Validation Accuracy: 0.7150
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0474 | Validation Accuracy: 0.7062
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0534 | Validation Accuracy: 0.7202
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0151 | Validation Accuracy: 0.7198
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0498 | Validation Accuracy: 0.7058
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0502 | Validation Accuracy: 0.6730
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0691 | Validation Accuracy: 0.7254
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0400 | Validation Accuracy: 0.7162
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0144 | Validation Accuracy: 0.7228
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.1189 | Validation Accuracy: 0.6966
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0351 | Validation Accuracy: 0.7100
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0833 | Validation Accuracy: 0.6998
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0459 | Validation Accuracy: 0.7146
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0080 | Validation Accuracy: 0.7250
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0424 | Validation Accuracy: 0.7174
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0121 | Validation Accuracy: 0.7026
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0360 | Validation Accuracy: 0.7186
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0467 | Validation Accuracy: 0.7144
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0036 | Validation Accuracy: 0.7254
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0422 | Validation Accuracy: 0.7152
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0090 | Validation Accuracy: 0.7104
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0561 | Validation Accuracy: 0.7106
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0296 | Validation Accuracy: 0.7242
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0087 | Validation Accuracy: 0.7196
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0180 | Validation Accuracy: 0.7214
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0282 | Validation Accuracy: 0.7176
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0567 | Validation Accuracy: 0.7136
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0269 | Validation Accuracy: 0.7098
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0090 | Validation Accuracy: 0.7274
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0045 | Validation Accuracy: 0.7178
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0063 | Validation Accuracy: 0.7196
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0330 | Validation Accuracy: 0.7208
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0248 | Validation Accuracy: 0.6944
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0039 | Validation Accuracy: 0.7294
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0070 | Validation Accuracy: 0.7212
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0030 | Validation Accuracy: 0.7140
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0446 | Validation Accuracy: 0.7276
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0148 | Validation Accuracy: 0.7072
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0027 | Validation Accuracy: 0.7288
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0053 | Validation Accuracy: 0.7204
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0074 | Validation Accuracy: 0.7166
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0140 | Validation Accuracy: 0.7082
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0155 | Validation Accuracy: 0.7104
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0073 | Validation Accuracy: 0.7292
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0084 | Validation Accuracy: 0.7246
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0160 | Validation Accuracy: 0.7134
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0221 | Validation Accuracy: 0.7204
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0063 | Validation Accuracy: 0.7272
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0061 | Validation Accuracy: 0.7322
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0041 | Validation Accuracy: 0.7218
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0055 | Validation Accuracy: 0.7310
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0492 | Validation Accuracy: 0.7278
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0144 | Validation Accuracy: 0.7230
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0019 | Validation Accuracy: 0.7184
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0148 | Validation Accuracy: 0.7258
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0429 | Validation Accuracy: 0.7182
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0155 | Validation Accuracy: 0.7294
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0270 | Validation Accuracy: 0.7178
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0032 | Validation Accuracy: 0.7210
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0232 | Validation Accuracy: 0.7142
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0039 | Validation Accuracy: 0.7232
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0113 | Validation Accuracy: 0.7302
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0105 | Validation Accuracy: 0.7250
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0044 | Validation Accuracy: 0.7192
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0132 | Validation Accuracy: 0.7210
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0066 | Validation Accuracy: 0.7198
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0120 | Validation Accuracy: 0.7276
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0053 | Validation Accuracy: 0.7192
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0114 | Validation Accuracy: 0.7138
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0267 | Validation Accuracy: 0.7126
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0019 | Validation Accuracy: 0.7152
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0148 | Validation Accuracy: 0.7346
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0031 | Validation Accuracy: 0.7296
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0027 | Validation Accuracy: 0.7196
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0171 | Validation Accuracy: 0.7126
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0024 | Validation Accuracy: 0.7248
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0022 | Validation Accuracy: 0.7244
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0057 | Validation Accuracy: 0.7172
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0014 | Validation Accuracy: 0.7244
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0082 | Validation Accuracy: 0.7200
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0012 | Validation Accuracy: 0.7304
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0248 | Validation Accuracy: 0.7188
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0010 | Validation Accuracy: 0.7212
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7142
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0081 | Validation Accuracy: 0.7160
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0029 | Validation Accuracy: 0.7232
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0163 | Validation Accuracy: 0.7156
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0086 | Validation Accuracy: 0.7198
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0052 | Validation Accuracy: 0.7278
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0060 | Validation Accuracy: 0.7028
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0015 | Validation Accuracy: 0.7182
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0072 | Validation Accuracy: 0.7132
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0080 | Validation Accuracy: 0.7242
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0008 | Validation Accuracy: 0.7192
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0014 | Validation Accuracy: 0.7206
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0114 | Validation Accuracy: 0.7192
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0026 | Validation Accuracy: 0.7294
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0078 | Validation Accuracy: 0.7216
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7230
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0026 | Validation Accuracy: 0.7220
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0025 | Validation Accuracy: 0.7228
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0047 | Validation Accuracy: 0.7226
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0010 | Validation Accuracy: 0.7234
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0253 | Validation Accuracy: 0.7278
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0019 | Validation Accuracy: 0.7312
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0009 | Validation Accuracy: 0.7202
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0190 | Validation Accuracy: 0.7178
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0051 | Validation Accuracy: 0.7238
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0010 | Validation Accuracy: 0.7222
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0010 | Validation Accuracy: 0.7316
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0185 | Validation Accuracy: 0.7152
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0405 | Validation Accuracy: 0.7168
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0058 | Validation Accuracy: 0.7224
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0016 | Validation Accuracy: 0.7148
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0079 | Validation Accuracy: 0.7232
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0165 | Validation Accuracy: 0.7068
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0166 | Validation Accuracy: 0.7264
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0002 | Validation Accuracy: 0.7294
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0009 | Validation Accuracy: 0.7242
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0005 | Validation Accuracy: 0.7330
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0023 | Validation Accuracy: 0.7240
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0231 | Validation Accuracy: 0.7280
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0064 | Validation Accuracy: 0.7316
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7310
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0002 | Validation Accuracy: 0.7248
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0040 | Validation Accuracy: 0.7164
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0124 | Validation Accuracy: 0.7278
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0012 | Validation Accuracy: 0.7246
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0010 | Validation Accuracy: 0.7304
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0041 | Validation Accuracy: 0.6980
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0075 | Validation Accuracy: 0.7176
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0056 | Validation Accuracy: 0.7142
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0539 | Validation Accuracy: 0.7200
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0019 | Validation Accuracy: 0.7160
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0094 | Validation Accuracy: 0.7132
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0123 | Validation Accuracy: 0.7188
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0119 | Validation Accuracy: 0.7248
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0042 | Validation Accuracy: 0.7224
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0048 | Validation Accuracy: 0.7268
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7280
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0002 | Validation Accuracy: 0.7252
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0015 | Validation Accuracy: 0.7266
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0020 | Validation Accuracy: 0.7142
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0012 | Validation Accuracy: 0.7312
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7256
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0096 | Validation Accuracy: 0.7192
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0121 | Validation Accuracy: 0.7078
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0059 | Validation Accuracy: 0.7244
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0238 | Validation Accuracy: 0.7222
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0002 | Validation Accuracy: 0.7346
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0833 | Validation Accuracy: 0.7308
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0024 | Validation Accuracy: 0.7310
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0023 | Validation Accuracy: 0.7122
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7192
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0020 | Validation Accuracy: 0.7154
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0008 | Validation Accuracy: 0.7276
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0034 | Validation Accuracy: 0.7136
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0006 | Validation Accuracy: 0.7294
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7280
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.7244
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0011 | Validation Accuracy: 0.7216
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0101 | Validation Accuracy: 0.7228
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7302
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0068 | Validation Accuracy: 0.7254
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0023 | Validation Accuracy: 0.7182
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0036 | Validation Accuracy: 0.7212
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0013 | Validation Accuracy: 0.7338
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7276
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7330
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0016 | Validation Accuracy: 0.7216
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0012 | Validation Accuracy: 0.7248
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0148 | Validation Accuracy: 0.7316
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0007 | Validation Accuracy: 0.7234
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7360
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0014 | Validation Accuracy: 0.7232
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0138 | Validation Accuracy: 0.7244
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0180 | Validation Accuracy: 0.7272
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0003 | Validation Accuracy: 0.7262
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0122 | Validation Accuracy: 0.7434
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0003 | Validation Accuracy: 0.7334
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0034 | Validation Accuracy: 0.7222
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.7366
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0107 | Validation Accuracy: 0.7346
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0075 | Validation Accuracy: 0.7346
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7266
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0005 | Validation Accuracy: 0.7248
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.7294
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0002 | Validation Accuracy: 0.7290
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7294
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0444 | Validation Accuracy: 0.7242
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0062 | Validation Accuracy: 0.7310
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0029 | Validation Accuracy: 0.7266
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0008 | Validation Accuracy: 0.7338
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0044 | Validation Accuracy: 0.7366
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0012 | Validation Accuracy: 0.7214
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0023 | Validation Accuracy: 0.7244
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0029 | Validation Accuracy: 0.7290
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0006 | Validation Accuracy: 0.7306
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7260
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0029 | Validation Accuracy: 0.7146
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0008 | Validation Accuracy: 0.7242
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0005 | Validation Accuracy: 0.7264
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7212
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7222
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0043 | Validation Accuracy: 0.7244
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0002 | Validation Accuracy: 0.7244
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0263 | Validation Accuracy: 0.7374
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0006 | Validation Accuracy: 0.7302
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0006 | Validation Accuracy: 0.7308
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0004 | Validation Accuracy: 0.7208
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0024 | Validation Accuracy: 0.7174
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0008 | Validation Accuracy: 0.7306
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0033 | Validation Accuracy: 0.7346
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0007 | Validation Accuracy: 0.7322
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0011 | Validation Accuracy: 0.7294
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0001 | Validation Accuracy: 0.7368
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0019 | Validation Accuracy: 0.7292
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0227 | Validation Accuracy: 0.7332
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0007 | Validation Accuracy: 0.7336
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0130 | Validation Accuracy: 0.7252
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7282
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0009 | Validation Accuracy: 0.7286
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7284
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0039 | Validation Accuracy: 0.7340
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0049 | Validation Accuracy: 0.7208
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0116 | Validation Accuracy: 0.7278
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0086 | Validation Accuracy: 0.7360
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0005 | Validation Accuracy: 0.7350
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7352
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0007 | Validation Accuracy: 0.7358
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0014 | Validation Accuracy: 0.7262
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0025 | Validation Accuracy: 0.7406
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0015 | Validation Accuracy: 0.7342
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0046 | Validation Accuracy: 0.7284
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0046 | Validation Accuracy: 0.7400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7340
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0010 | Validation Accuracy: 0.7410
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7382
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7374
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0076 | Validation Accuracy: 0.7302
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7336
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0039 | Validation Accuracy: 0.7420
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7342
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7364
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7218
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7308
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0003 | Validation Accuracy: 0.7370
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0011 | Validation Accuracy: 0.7268
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0272 | Validation Accuracy: 0.7340
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7434
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0001 | Validation Accuracy: 0.7300
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0107 | Validation Accuracy: 0.7394
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7330
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7392
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7350
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0009 | Validation Accuracy: 0.7384
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0049 | Validation Accuracy: 0.7326
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.7324
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0004 | Validation Accuracy: 0.7232
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0046 | Validation Accuracy: 0.7398
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7282
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0066 | Validation Accuracy: 0.7322
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0014 | Validation Accuracy: 0.7278
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0056 | Validation Accuracy: 0.7350
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0003 | Validation Accuracy: 0.7352
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0005 | Validation Accuracy: 0.7480
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0006 | Validation Accuracy: 0.7310
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0002 | Validation Accuracy: 0.7290
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0019 | Validation Accuracy: 0.7266
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0004 | Validation Accuracy: 0.7368
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7416
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0001 | Validation Accuracy: 0.7322
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0003 | Validation Accuracy: 0.7282
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7418
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0008 | Validation Accuracy: 0.7342
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0005 | Validation Accuracy: 0.7282
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0029 | Validation Accuracy: 0.7364
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.7334
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7398
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7368
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7372
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0020 | Validation Accuracy: 0.7350
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.7302
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7396
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0009 | Validation Accuracy: 0.7152
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0002 | Validation Accuracy: 0.7218
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0010 | Validation Accuracy: 0.7302
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0014 | Validation Accuracy: 0.7286
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7320
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0171 | Validation Accuracy: 0.7342
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0498 | Validation Accuracy: 0.7264
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.7358
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0038 | Validation Accuracy: 0.7284
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0032 | Validation Accuracy: 0.7302
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0009 | Validation Accuracy: 0.7320
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7360
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0003 | Validation Accuracy: 0.7322
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0026 | Validation Accuracy: 0.7392
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0019 | Validation Accuracy: 0.7350
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7426
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7322
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0063 | Validation Accuracy: 0.7380
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0014 | Validation Accuracy: 0.7360
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7396
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0204 | Validation Accuracy: 0.7298
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0033 | Validation Accuracy: 0.7302
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0005 | Validation Accuracy: 0.7416
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0009 | Validation Accuracy: 0.7322
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0026 | Validation Accuracy: 0.7326
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0023 | Validation Accuracy: 0.7410
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7396
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0005 | Validation Accuracy: 0.7378
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0052 | Validation Accuracy: 0.7284
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7356
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.7358
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0001 | Validation Accuracy: 0.7260
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0083 | Validation Accuracy: 0.7320
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0002 | Validation Accuracy: 0.7298
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0015 | Validation Accuracy: 0.7358
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0006 | Validation Accuracy: 0.7354
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0005 | Validation Accuracy: 0.7290
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0002 | Validation Accuracy: 0.7414
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0002 | Validation Accuracy: 0.7356
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0019 | Validation Accuracy: 0.7348
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0004 | Validation Accuracy: 0.7342
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0005 | Validation Accuracy: 0.7210
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0004 | Validation Accuracy: 0.7424
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0195 | Validation Accuracy: 0.7188
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0026 | Validation Accuracy: 0.7290
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.7292
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0014 | Validation Accuracy: 0.7416
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0010 | Validation Accuracy: 0.7242
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0011 | Validation Accuracy: 0.7262
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7296
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.7370
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0005 | Validation Accuracy: 0.7332
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.7300
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0007 | Validation Accuracy: 0.7320
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0082 | Validation Accuracy: 0.7412
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0011 | Validation Accuracy: 0.7458
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7362
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0004 | Validation Accuracy: 0.7300
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0002 | Validation Accuracy: 0.7300
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0003 | Validation Accuracy: 0.7370
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0102 | Validation Accuracy: 0.7342
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0002 | Validation Accuracy: 0.7360
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0012 | Validation Accuracy: 0.7366
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.7350
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7348
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0016 | Validation Accuracy: 0.7410
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7366
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.7300
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7206
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0001 | Validation Accuracy: 0.7412
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0076 | Validation Accuracy: 0.7382
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7384
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0022 | Validation Accuracy: 0.7340
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0001 | Validation Accuracy: 0.7370
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7354
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.7384
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7390
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0005 | Validation Accuracy: 0.7298
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0037 | Validation Accuracy: 0.7356
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0019 | Validation Accuracy: 0.7332
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0008 | Validation Accuracy: 0.7322
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0008 | Validation Accuracy: 0.7372
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.7336
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0078 | Validation Accuracy: 0.7316
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0002 | Validation Accuracy: 0.7404
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0004 | Validation Accuracy: 0.7384
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0001 | Validation Accuracy: 0.7316
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0003 | Validation Accuracy: 0.7374
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0089 | Validation Accuracy: 0.7362
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.7324
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0018 | Validation Accuracy: 0.7348
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0004 | Validation Accuracy: 0.7266
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0006 | Validation Accuracy: 0.7364
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0012 | Validation Accuracy: 0.7404
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0002 | Validation Accuracy: 0.7324
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0001 | Validation Accuracy: 0.7300
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.7370
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0050 | Validation Accuracy: 0.7418
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0002 | Validation Accuracy: 0.7406
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0004 | Validation Accuracy: 0.7386
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0002 | Validation Accuracy: 0.7288
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0001 | Validation Accuracy: 0.7314

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7188488924050633

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
