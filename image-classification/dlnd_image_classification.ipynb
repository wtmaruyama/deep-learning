# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # Implement Min-Max for RGB [0,255]
    min_interval = 0
    max_interval = 1
    colorscale_min = 0
    colorscale_max = 255
    return  min_interval + (((x - colorscale_min)*(max_interval - min_interval))/(colorscale_max - colorscale_min))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing

# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html
lb = preprocessing.LabelBinarizer()
lb.fit(range(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    batch = None
    size = [batch,image_shape[0],image_shape[1],image_shape[2]] # H x W x D

    return tf.placeholder(tf.float32,shape=size,name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    batch = None
    size = [batch,n_classes]
    return tf.placeholder(tf.float32,shape=size,name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    # Output depth
    k_output = conv_num_outputs
    
    # Weight and bias
    ## Image Properties
    # batch_size = x_tensor.get_shape().as_list()[0]
    # image_width = x_tensor.get_shape().as_list()[1]
    # image_height = x_tensor.get_shape().as_list()[2]
    color_channels = x_tensor.get_shape().as_list()[3]

    # Convolution filter
    filter_size_width = conv_ksize[0]
    filter_size_height = conv_ksize[1]
    
    # Weight and bias
    # (altura, largura, profundidade do input, profundidade do output)
    weights = tf.Variable(tf.truncated_normal([filter_size_height, filter_size_width, color_channels, k_output])) 
    bias = tf.Variable(tf.zeros(k_output))
     
    
    # Apply Convolution
    # (lote, altura, largura, profundidade)
    stride = [1, conv_strides[0], conv_strides[1], 1]
    conv_layer = tf.nn.conv2d(input=x_tensor, filter=weights, strides=stride, padding='SAME')
    
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    # Apply activation function
    conv_layer = tf.nn.relu(conv_layer)
    
    # Apply max-pooling
    conv_layer = tf.nn.max_pool(conv_layer, \
                                ksize=[1, pool_ksize[0], pool_ksize[1], 1], \
                                strides=[1, pool_strides[0], pool_strides[1], 1], \
                                padding='SAME')
    return conv_layer 



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    x_list = x_tensor.get_shape().as_list()
    batch_size = x_list[0]
    image_width = x_list[1]
    image_height = x_list[2]
    depth = x_list[3]
    
    flattened = int(image_height * image_width * depth)
    
    return tf.reshape(x_tensor, [-1, flattened])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    num_in = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.random_normal([num_in, num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    # Multiply input by weights and add bias
    fully_conn = tf.add(tf.matmul(x_tensor, weights), bias)
    
    # Apply activation function
    fully_conn = tf.nn.relu(fully_conn)
    
    return fully_conn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    num_in = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.random_normal([num_in, num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    # Multiply input by weights and add bias
    output = tf.add(tf.matmul(x_tensor, weights), bias)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # Variable initialization
    conv_ksize = (3, 3)
    conv_strides = (2, 2)
    pool_ksize = (2, 2)
    pool_strides = (1, 1)
    conv_num_outputs = 48
    
    # layer 1 - 32x32x3 to 16x16x48
    conv_layer = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # layer 2 - 16x16x48 to 8x8x192
    conv_layer = conv2d_maxpool(conv_layer, 192, (2, 2), conv_strides, pool_ksize, (1, 1))
    
    # layer 3 - 8x8x192 to 4x4x384
    conv_layer = conv2d_maxpool(conv_layer, 384, (2, 2), conv_strides, (1, 1), pool_strides)
    
    # layer 4 - 4x4x384 to 2x2x512
    conv_layer = conv2d_maxpool(conv_layer, 512, (2, 2), (2, 2), (1, 1), (1, 1))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    # 2x2x512 to 2048
    conv_layer = flatten(conv_layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    # Dropout
    fully_conn_layer = tf.nn.dropout(conv_layer, keep_prob) # (keep_prob * 3072)
    
    # Fully connected layer 1 -- (keep_prob * 3072) to 512
    fully_conn_layer = fully_conn(conv_layer, 512)
    
    # Fully connected layer 2 -- 512 to 128
    fully_conn_layer = fully_conn(fully_conn_layer, 128)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    # Output layer -- 128 to 10
    out = output(fully_conn_layer, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    
    session.run(optimizer, feed_dict={
        x: feature_batch, 
        y: label_batch, 
        keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
    x: feature_batch, 
    y: label_batch,
    keep_prob: 1.0})
    
    valid_accuracy = session.run(accuracy, feed_dict={
    x: valid_features,
    y: valid_labels,
    keep_prob: 1.0})
        
    print('Loss: {:>10.4f} | Validation Accuracy: {:.4f}'.format(
        loss,
        valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 500
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 4666057.0000 | Validation Accuracy: 0.2434
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2342835.5000 | Validation Accuracy: 0.2794
# Epoch  3, CIFAR-10 Batch 1:  Loss: 1919607.3750 | Validation Accuracy: 0.2986
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1631823.5000 | Validation Accuracy: 0.3216
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1172468.2500 | Validation Accuracy: 0.3274
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1001785.7500 | Validation Accuracy: 0.3350
# Epoch  7, CIFAR-10 Batch 1:  Loss: 940109.8750 | Validation Accuracy: 0.3368
# Epoch  8, CIFAR-10 Batch 1:  Loss: 807058.0625 | Validation Accuracy: 0.3326
# Epoch  9, CIFAR-10 Batch 1:  Loss: 674879.3750 | Validation Accuracy: 0.3380
# Epoch 10, CIFAR-10 Batch 1:  Loss: 530592.6250 | Validation Accuracy: 0.3386
# Epoch 11, CIFAR-10 Batch 1:  Loss: 450000.9375 | Validation Accuracy: 0.3480
# Epoch 12, CIFAR-10 Batch 1:  Loss: 396374.2500 | Validation Accuracy: 0.3604
# Epoch 13, CIFAR-10 Batch 1:  Loss: 371292.8438 | Validation Accuracy: 0.3680
# Epoch 14, CIFAR-10 Batch 1:  Loss: 378641.8438 | Validation Accuracy: 0.3734
# Epoch 15, CIFAR-10 Batch 1:  Loss: 353628.0312 | Validation Accuracy: 0.3790
# Epoch 16, CIFAR-10 Batch 1:  Loss: 358453.6250 | Validation Accuracy: 0.3664
# Epoch 17, CIFAR-10 Batch 1:  Loss: 305148.9062 | Validation Accuracy: 0.3650
# Epoch 18, CIFAR-10 Batch 1:  Loss: 178016.5938 | Validation Accuracy: 0.3824
# Epoch 19, CIFAR-10 Batch 1:  Loss: 174906.5156 | Validation Accuracy: 0.3798
# Epoch 20, CIFAR-10 Batch 1:  Loss: 135370.5625 | Validation Accuracy: 0.3690
# Epoch 21, CIFAR-10 Batch 1:  Loss: 117328.1016 | Validation Accuracy: 0.3888
# Epoch 22, CIFAR-10 Batch 1:  Loss: 175360.2656 | Validation Accuracy: 0.3762
# Epoch 23, CIFAR-10 Batch 1:  Loss: 159465.5781 | Validation Accuracy: 0.3806
# Epoch 24, CIFAR-10 Batch 1:  Loss: 193570.5469 | Validation Accuracy: 0.3868
# Epoch 25, CIFAR-10 Batch 1:  Loss: 124284.6484 | Validation Accuracy: 0.3932
# Epoch 26, CIFAR-10 Batch 1:  Loss: 137633.3125 | Validation Accuracy: 0.3894
# Epoch 186, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4680
# Epoch 187, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4810
# Epoch 188, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4622
# Epoch 189, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4796
# Epoch 190, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4654
# Epoch 191, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4826
# Epoch 192, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4710
# Epoch 193, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4698
# Epoch 194, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4764
# Epoch 195, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4722
# Epoch 196, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4686
# Epoch 197, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4720
# Epoch 198, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4786
# Epoch 199, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4730
# Epoch 200, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4758
# Epoch 201, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4836
# Epoch 202, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4756
# Epoch 203, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4634
# Epoch 204, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4620
# Epoch 205, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4760
# Epoch 206, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4632
# Epoch 207, CIFAR-10 Batch 1:  Loss:  4849.5439 | Validation Accuracy: 0.4654
# Epoch 208, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4584
# Epoch 209, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4768
# Epoch 210, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4712
# Epoch 211, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4748
# Epoch 212, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4698
# Epoch 213, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4686
# Epoch 214, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4744
# Epoch 215, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4826
# Epoch 216, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4712
# Epoch 217, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4788
# Epoch 218, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4640
# Epoch 219, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4820
# Epoch 220, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4706
# Epoch 221, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4814
# Epoch 222, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4780
# Epoch 223, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4804
# Epoch 224, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4758
# Epoch 225, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4810
# Epoch 226, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4828
# Epoch 227, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4748
# Epoch 228, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4770
# Epoch 229, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4802
# Epoch 230, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4752
# Epoch 231, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4876
# Epoch 232, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4796
# Epoch 233, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4750
# Epoch 234, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4722
# Epoch 235, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4966
# Epoch 236, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4808
# Epoch 237, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4856
# Epoch 238, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4860
# Epoch 239, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4752
# Epoch 240, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4912
# Epoch 241, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4824
# Epoch 242, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4878
# Epoch 243, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4840
# Epoch 244, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4674
# Epoch 245, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4668
# Epoch 246, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4878
# Epoch 247, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4966
# Epoch 248, CIFAR-10 Batch 1:  Loss:  3843.9570 | Validation Accuracy: 0.4606
# Epoch 249, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4820
# Epoch 250, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4706
# Epoch 251, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4708
# Epoch 252, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4784
# Epoch 253, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4800
# Epoch 254, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4806
# Epoch 255, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4860
# Epoch 256, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4698
# Epoch 257, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4702
# Epoch 258, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4862
# Epoch 259, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4728
# Epoch 260, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4718
# Epoch 261, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4684
# Epoch 262, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4718
# Epoch 263, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4516
# Epoch 264, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4740
# Epoch 265, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4774
# Epoch 266, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4892
# Epoch 267, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4900
# Epoch 268, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4806
# Epoch 269, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4936
# Epoch 270, CIFAR-10 Batch 1:  Loss:   640.6656 | Validation Accuracy: 0.4782
# Epoch 271, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4878
# Epoch 272, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4930
# Epoch 273, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4908
# Epoch 274, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4678
# Epoch 275, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4828
# Epoch 276, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4848
# Epoch 277, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4940
# Epoch 278, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4896
# Epoch 279, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4948
# Epoch 280, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4858
# Epoch 281, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4862
# Epoch 282, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4814
# Epoch 283, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4774
# Epoch 284, CIFAR-10 Batch 1:  Loss:    28.4031 | Validation Accuracy: 0.4844
# Epoch 285, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5030
# Epoch 286, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4862
# Epoch 287, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4786
# Epoch 288, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4878
# Epoch 289, CIFAR-10 Batch 1:  Loss:   692.8813 | Validation Accuracy: 0.4924
# Epoch 290, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4838
# Epoch 291, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4922
# Epoch 292, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4704
# Epoch 293, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4888
# Epoch 294, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4794
# Epoch 295, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4818
# Epoch 296, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4876
# Epoch 297, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4990
# Epoch 298, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4882
# Epoch 299, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4974
# Epoch 300, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4912
# Epoch 301, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4810
# Epoch 302, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4980
# Epoch 303, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4932
# Epoch 304, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4928
# Epoch 305, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4826
# Epoch 306, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4910
# Epoch 307, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4990
# Epoch 308, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4832
# Epoch 309, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4980
# Epoch 310, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4950
# Epoch 311, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4846
# Epoch 312, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4926
# Epoch 313, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4932
# Epoch 314, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4910
# Epoch 315, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4724
# Epoch 316, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.
# Epoch 13, CIFAR-10 Batch 5:  Loss: 46847.9922 | Validation Accuracy: 0.4132
# Epoch 14, CIFAR-10 Batch 1:  Loss: 57454.1797 | Validation Accuracy: 0.4346
# Epoch 14, CIFAR-10 Batch 2:  Loss: 37570.2031 | Validation Accuracy: 0.4272
# Epoch 14, CIFAR-10 Batch 3:  Loss: 16151.7012 | Validation Accuracy: 0.4324
# Epoch 14, CIFAR-10 Batch 4:  Loss: 42942.4375 | Validation Accuracy: 0.4324
# Epoch 14, CIFAR-10 Batch 5:  Loss: 35845.4922 | Validation Accuracy: 0.4212
# Epoch 15, CIFAR-10 Batch 1:  Loss: 52612.9570 | Validation Accuracy: 0.4352
# Epoch 15, CIFAR-10 Batch 2:  Loss: 27800.1094 | Validation Accuracy: 0.4264
# Epoch 15, CIFAR-10 Batch 3:  Loss: 13932.7500 | Validation Accuracy: 0.4340
# Epoch 15, CIFAR-10 Batch 4:  Loss: 29828.3086 | Validation Accuracy: 0.4334
# Epoch 15, CIFAR-10 Batch 5:  Loss: 30712.1133 | Validation Accuracy: 0.4324
# Epoch 16, CIFAR-10 Batch 1:  Loss: 39404.4648 | Validation Accuracy: 0.4350
# Epoch 16, CIFAR-10 Batch 2:  Loss: 21568.5000 | Validation Accuracy: 0.4322
# Epoch 16, CIFAR-10 Batch 3:  Loss: 10125.6699 | Validation Accuracy: 0.4334
# Epoch 16, CIFAR-10 Batch 4:  Loss: 26022.9297 | Validation Accuracy: 0.4380
# Epoch 16, CIFAR-10 Batch 5:  Loss: 21990.7070 | Validation Accuracy: 0.4272
# Epoch 17, CIFAR-10 Batch 1:  Loss: 28968.4004 | Validation Accuracy: 0.4380
# Epoch 17, CIFAR-10 Batch 2:  Loss: 18868.4922 | Validation Accuracy: 0.4364
# Epoch 17, CIFAR-10 Batch 3:  Loss:  9145.3584 | Validation Accuracy: 0.4332
# Epoch 17, CIFAR-10 Batch 4:  Loss: 30118.5957 | Validation Accuracy: 0.4418
# Epoch 17, CIFAR-10 Batch 5:  Loss: 15272.5820 | Validation Accuracy: 0.4272
# Epoch 18, CIFAR-10 Batch 1:  Loss: 28152.3086 | Validation Accuracy: 0.4412
# Epoch 18, CIFAR-10 Batch 2:  Loss: 16149.8672 | Validation Accuracy: 0.4374
# Epoch 18, CIFAR-10 Batch 3:  Loss:  7049.4116 | Validation Accuracy: 0.4366
# Epoch 18, CIFAR-10 Batch 4:  Loss: 22179.6133 | Validation Accuracy: 0.4416
# Epoch 18, CIFAR-10 Batch 5:  Loss: 13101.4043 | Validation Accuracy: 0.4424
# Epoch 19, CIFAR-10 Batch 1:  Loss: 21242.2715 | Validation Accuracy: 0.4430
# Epoch 19, CIFAR-10 Batch 2:  Loss: 13115.0029 | Validation Accuracy: 0.4376
# Epoch 19, CIFAR-10 Batch 3:  Loss:  4072.4944 | Validation Accuracy: 0.4394
# Epoch 19, CIFAR-10 Batch 4:  Loss: 21611.3535 | Validation Accuracy: 0.4432
# Epoch 19, CIFAR-10 Batch 5:  Loss:  8265.7441 | Validation Accuracy: 0.4464
# Epoch 20, CIFAR-10 Batch 1:  Loss: 17538.5703 | Validation Accuracy: 0.4450
# Epoch 20, CIFAR-10 Batch 2:  Loss:  9348.6875 | Validation Accuracy: 0.4512
# Epoch 20, CIFAR-10 Batch 3:  Loss:  2182.3372 | Validation Accuracy: 0.4528
# Epoch 20, CIFAR-10 Batch 4:  Loss: 20631.0664 | Validation Accuracy: 0.4528
# Epoch 20, CIFAR-10 Batch 5:  Loss:  6212.1846 | Validation Accuracy: 0.4376
# Epoch 21, CIFAR-10 Batch 1:  Loss: 12429.9932 | Validation Accuracy: 0.4500
# Epoch 21, CIFAR-10 Batch 2:  Loss:  7985.9775 | Validation Accuracy: 0.4420
# Epoch 21, CIFAR-10 Batch 3:  Loss:  3687.8145 | Validation Accuracy: 0.4452
# Epoch 21, CIFAR-10 Batch 4:  Loss: 17387.5020 | Validation Accuracy: 0.4524
# Epoch 21, CIFAR-10 Batch 5:  Loss: 10356.7217 | Validation Accuracy: 0.4502
# Epoch 22, CIFAR-10 Batch 1:  Loss: 10237.6875 | Validation Accuracy: 0.4474
# Epoch 22, CIFAR-10 Batch 2:  Loss:  8578.4209 | Validation Accuracy: 0.4524
# Epoch 22, CIFAR-10 Batch 3:  Loss:  3921.8467 | Validation Accuracy: 0.4540
# Epoch 22, CIFAR-10 Batch 4:  Loss: 13760.8164 | Validation Accuracy: 0.4544
# Epoch 22, CIFAR-10 Batch 5:  Loss:  6276.7764 | Validation Accuracy: 0.4364
# Epoch 23, CIFAR-10 Batch 1:  Loss:  6727.8418 | Validation Accuracy: 0.4492
# Epoch 23, CIFAR-10 Batch 2:  Loss:  6974.2993 | Validation Accuracy: 0.4496
# Epoch 23, CIFAR-10 Batch 3:  Loss:  1736.1338 | Validation Accuracy: 0.4464
# Epoch 23, CIFAR-10 Batch 4:  Loss:  9775.5166 | Validation Accuracy: 0.4382
# Epoch 23, CIFAR-10 Batch 5:  Loss:  4085.3528 | Validation Accuracy: 0.4342
# Epoch 24, CIFAR-10 Batch 1:  Loss:  7456.6631 | Validation Accuracy: 0.4542
# Epoch 24, CIFAR-10 Batch 2:  Loss:  7808.1904 | Validation Accuracy: 0.4578
# Epoch 24, CIFAR-10 Batch 3:  Loss:  1983.8395 | Validation Accuracy: 0.4536
# Epoch 24, CIFAR-10 Batch 4:  Loss:  9949.7109 | Validation Accuracy: 0.4354
# Epoch 24, CIFAR-10 Batch 5:  Loss:  6170.2705 | Validation Accuracy: 0.4386
# Epoch 25, CIFAR-10 Batch 1:  Loss:  4987.7578 | Validation Accuracy: 0.4566
# Epoch 25, CIFAR-10 Batch 2:  Loss:  7059.4062 | Validation Accuracy: 0.4446
# Epoch 25, CIFAR-10 Batch 3:  Loss:  1414.3916 | Validation Accuracy: 0.4548
# Epoch 25, CIFAR-10 Batch 4:  Loss:  6991.9463 | Validation Accuracy: 0.4414
# Epoch 25, CIFAR-10 Batch 5:  Loss:  5288.2168 | Validation Accuracy: 0.4302
# Epoch 26, CIFAR-10 Batch 1:  Loss:  3070.4568 | Validation Accuracy: 0.4610
# Epoch 26, CIFAR-10 Batch 2:  Loss:  4783.6201 | Validation Accuracy: 0.4490
# Epoch 26, CIFAR-10 Batch 3:  Loss:  1997.4807 | Validation Accuracy: 0.4564
# Epoch 26, CIFAR-10 Batch 4:  Loss:  6553.4888 | Validation Accuracy: 0.4470
# Epoch 26, CIFAR-10 Batch 5:  Loss:  2253.4871 | Validation Accuracy: 0.4280
# Epoch 27, CIFAR-10 Batch 1:  Loss:   460.8412 | Validation Accuracy: 0.4552
# Epoch 27, CIFAR-10 Batch 2:  Loss:  4972.0654 | Validation Accuracy: 0.4384
# Epoch 27, CIFAR-10 Batch 3:  Loss:  1226.4547 | Validation Accuracy: 0.4622
# Epoch 27, CIFAR-10 Batch 4:  Loss:  4182.8940 | Validation Accuracy: 0.4600
# Epoch 27, CIFAR-10 Batch 5:  Loss:   512.2633 | Validation Accuracy: 0.4354
# Epoch 28, CIFAR-10 Batch 1:  Loss:  1665.5442 | Validation Accuracy: 0.4524
# Epoch 28, CIFAR-10 Batch 2:  Loss:  5210.6094 | Validation Accuracy: 0.4360
# Epoch 28, CIFAR-10 Batch 3:  Loss:  1099.0137 | Validation Accuracy: 0.4542
# Epoch 28, CIFAR-10 Batch 4:  Loss:  4257.9272 | Validation Accuracy: 0.4556
# Epoch 28, CIFAR-10 Batch 5:  Loss:  2802.8721 | Validation Accuracy: 0.4450
# Epoch 29, CIFAR-10 Batch 1:  Loss:  1369.4380 | Validation Accuracy: 0.4748
# Epoch 29, CIFAR-10 Batch 2:  Loss:  3809.7075 | Validation Accuracy: 0.4398
# Epoch 29, CIFAR-10 Batch 3:  Loss:  1237.1012 | Validation Accuracy: 0.4598
# Epoch 29, CIFAR-10 Batch 4:  Loss:  2807.7373 | Validation Accuracy: 0.4696
# Epoch 29, CIFAR-10 Batch 5:  Loss:   144.4477 | Validation Accuracy: 0.4498
# Epoch 30, CIFAR-10 Batch 1:  Loss:   918.3282 | Validation Accuracy: 0.4604
# Epoch 30, CIFAR-10 Batch 2:  Loss:  2310.9517 | Validation Accuracy: 0.4438
# Epoch 30, CIFAR-10 Batch 3:  Loss:  1109.4934 | Validation Accuracy: 0.4544
# Epoch 30, CIFAR-10 Batch 4:  Loss:  2554.0527 | Validation Accuracy: 0.4644
# Epoch 30, CIFAR-10 Batch 5:  Loss:  2065.3323 | Validation Accuracy: 0.4400
# Epoch 31, CIFAR-10 Batch 1:  Loss:   574.5060 | Validation Accuracy: 0.4674
# Epoch 31, CIFAR-10 Batch 2:  Loss:  2424.9150 | Validation Accuracy: 0.4568
# Epoch 31, CIFAR-10 Batch 3:  Loss:   427.0199 | Validation Accuracy: 0.4666
# Epoch 31, CIFAR-10 Batch 4:  Loss:  1845.9844 | Validation Accuracy: 0.4646
# Epoch 31, CIFAR-10 Batch 5:  Loss:   191.9164 | Validation Accuracy: 0.4704
# Epoch 32, CIFAR-10 Batch 1:  Loss:   668.1483 | Validation Accuracy: 0.4680
# Epoch 32, CIFAR-10 Batch 2:  Loss:  1012.2833 | Validation Accuracy: 0.4624
# Epoch 32, CIFAR-10 Batch 3:  Loss:   270.3641 | Validation Accuracy: 0.4684
# Epoch 32, CIFAR-10 Batch 4:  Loss:  1930.3304 | Validation Accuracy: 0.4642
# Epoch 32, CIFAR-10 Batch 5:  Loss:   217.6918 | Validation Accuracy: 0.4522
# Epoch 33, CIFAR-10 Batch 1:  Loss:  1072.1677 | Validation Accuracy: 0.4694
# Epoch 33, CIFAR-10 Batch 2:  Loss:   936.0797 | Validation Accuracy: 0.4620
# Epoch 33, CIFAR-10 Batch 3:  Loss:   891.0145 | Validation Accuracy: 0.4700
# Epoch 33, CIFAR-10 Batch 4:  Loss:   606.7996 | Validation Accuracy: 0.4672
# Epoch 33, CIFAR-10 Batch 5:  Loss:    89.2621 | Validation Accuracy: 0.4584
# Epoch 34, CIFAR-10 Batch 1:  Loss:  1187.3625 | Validation Accuracy: 0.4552
# Epoch 34, CIFAR-10 Batch 2:  Loss:    28.5473 | Validation Accuracy: 0.4620
# Epoch 34, CIFAR-10 Batch 3:  Loss:   156.6648 | Validation Accuracy: 0.4818
# Epoch 34, CIFAR-10 Batch 4:  Loss:   595.3777 | Validation Accuracy: 0.4714
# Epoch 34, CIFAR-10 Batch 5:  Loss:  1151.5219 | Validation Accuracy: 0.4496
# Epoch 35, CIFAR-10 Batch 1:  Loss:   808.3969 | Validation Accuracy: 0.4648
# Epoch 35, CIFAR-10 Batch 2:  Loss:    55.7992 | Validation Accuracy: 0.4672
# Epoch 35, CIFAR-10 Batch 3:  Loss:   991.5012 | Validation Accuracy: 0.4772
# Epoch 35, CIFAR-10 Batch 4:  Loss:  1086.9893 | Validation Accuracy: 0.4788
# Epoch 35, CIFAR-10 Batch 5:  Loss:   162.4350 | Validation Accuracy: 0.4604
# Epoch 36, CIFAR-10 Batch 1:  Loss:  1846.9788 | Validation Accuracy: 0.4768
# Epoch 36, CIFAR-10 Batch 2:  Loss:   136.6621 | Validation Accuracy: 0.4762
# Epoch 36, CIFAR-10 Batch 3:  Loss:  1305.7783 | Validation Accuracy: 0.4770
# Epoch 36, CIFAR-10 Batch 4:  Loss:    77.9463 | Validation Accuracy: 0.4794
# Epoch 36, CIFAR-10 Batch 5:  Loss:   538.4948 | Validation Accuracy: 0.4598
# Epoch 37, CIFAR-10 Batch 1:  Loss:   171.2474 | Validation Accuracy: 0.4788
# Epoch 37, CIFAR-10 Batch 2:  Loss:   156.1629 | Validation Accuracy: 0.4692
# Epoch 37, CIFAR-10 Batch 3:  Loss:   367.2043 | Validation Accuracy: 0.4736
# Epoch 37, CIFAR-10 Batch 4:  Loss:  1214.8782 | Validation Accuracy: 0.4756
# Epoch 37, CIFAR-10 Batch 5:  Loss:   285.9223 | Validation Accuracy: 0.4614
# Epoch 38, CIFAR-10 Batch 1:  Loss:   761.6387 | Validation Accuracy: 0.4766
# Epoch 38, CIFAR-10 Batch 2:  Loss:   245.1012 | Validation Accuracy: 0.4716
# Epoch 38, CIFAR-10 Batch 3:  Loss:    99.8895 | Validation Accuracy: 0.4696
# Epoch 38, CIFAR-10 Batch 4:  Loss:  1123.6718 | Validation Accuracy: 0.4896
# Epoch 38, CIFAR-10 Batch 5:  Loss:   462.6484 | Validation Accuracy: 0.4736
# Epoch 39, CIFAR-10 Batch 1:  Loss:  1761.8473 | Validation Accuracy: 0.4978
# Epoch 39, CIFAR-10 Batch 2:  Loss:   583.0379 | Validation Accuracy: 0.4768
# Epoch 39, CIFAR-10 Batch 3:  Loss:   487.5791 | Validation Accuracy: 0.4636
# Epoch 39, CIFAR-10 Batch 4:  Loss:  1672.0526 | Validation Accuracy: 0.4682
# Epoch 39, CIFAR-10 Batch 5:  Loss:   668.2168 | Validation Accuracy: 0.4806
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4956
# Epoch 40, CIFAR-10 Batch 2:  Loss:  1551.5928 | Validation Accuracy: 0.4948
# Epoch 40, CIFAR-10 Batch 3:  Loss:    77.1623 | Validation Accuracy: 0.4592
# Epoch 40, CIFAR-10 Batch 4:  Loss:  2096.2612 | Validation Accuracy: 0.4792
# Epoch 40, CIFAR-10 Batch 5:  Loss:    85.0258 | Validation Accuracy: 0.4696
# Epoch 41, CIFAR-10 Batch 1:  Loss:   516.3108 | Validation Accuracy: 0.4882
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4830
# Epoch 41, CIFAR-10 Batch 3:  Loss:   384.5111 | Validation Accuracy: 0.4728
# Epoch 41, CIFAR-10 Batch 4:  Loss:   145.0370 | Validation Accuracy: 0.4838
# Epoch 41, CIFAR-10 Batch 5:  Loss:   369.4137 | Validation Accuracy: 0.4618
# Epoch 42, CIFAR-10 Batch 1:  Loss:   272.5363 | Validation Accuracy: 0.5006
# Epoch 42, CIFAR-10 Batch 2:  Loss:   357.5672 | Validation Accuracy: 0.4704
# Epoch 42, CIFAR-10 Batch 3:  Loss:   766.5736 | Validation Accuracy: 0.4796
# Epoch 42, CIFAR-10 Batch 4:  Loss:  1173.6870 | Validation Accuracy: 0.4780
# Epoch 42, CIFAR-10 Batch 5:  Loss:   311.0918 | Validation Accuracy: 0.4640
# Epoch 43, CIFAR-10 Batch 1:  Loss:   515.0887 | Validation Accuracy: 0.4940
# Epoch 43, CIFAR-10 Batch 2:  Loss:   950.6641 | Validation Accuracy: 0.4694
# Epoch 43, CIFAR-10 Batch 3:  Loss:   594.9160 | Validation Accuracy: 0.4834
# Epoch 43, CIFAR-10 Batch 4:  Loss:  1285.8704 | Validation Accuracy: 0.4780
# Epoch 43, CIFAR-10 Batch 5:  Loss:   777.3586 | Validation Accuracy: 0.4632
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4920
# Epoch 44, CIFAR-10 Batch 2:  Loss:    65.0762 | Validation Accuracy: 0.4602
# Epoch 44, CIFAR-10 Batch 3:  Loss:    67.3414 | Validation Accuracy: 0.4746
# Epoch 44, CIFAR-10 Batch 4:  Loss:   293.3346 | Validation Accuracy: 0.4748
# Epoch 44, CIFAR-10 Batch 5:  Loss:    58.9939 | Validation Accuracy: 0.4628
# Epoch 45, CIFAR-10 Batch 1:  Loss:   450.6760 | Validation Accuracy: 0.4926
# Epoch 45, CIFAR-10 Batch 2:  Loss:   333.5664 | Validation Accuracy: 0.4740
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4850
# Epoch 45, CIFAR-10 Batch 4:  Loss:    50.2703 | Validation Accuracy: 0.4836
# Epoch 45, CIFAR-10 Batch 5:  Loss:   424.7170 | Validation Accuracy: 0.4532
# Epoch 46, CIFAR-10 Batch 1:  Loss:    52.6883 | Validation Accuracy: 0.4942
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4720
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4822
# Epoch 46, CIFAR-10 Batch 4:  Loss:  1017.1648 | Validation Accuracy: 0.4794
# Epoch 46, CIFAR-10 Batch 5:  Loss:   185.4513 | Validation Accuracy: 0.4750
# Epoch 47, CIFAR-10 Batch 1:  Loss:    15.8510 | Validation Accuracy: 0.4936
# Epoch 47, CIFAR-10 Batch 2:  Loss:   682.6457 | Validation Accuracy: 0.4764
# Epoch 47, CIFAR-10 Batch 3:  Loss:    66.9352 | Validation Accuracy: 0.4810
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4820
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4788
# Epoch 48, CIFAR-10 Batch 1:  Loss:   189.1715 | Validation Accuracy: 0.5008
# Epoch 48, CIFAR-10 Batch 2:  Loss:   668.8795 | Validation Accuracy: 0.4848
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4812
# Epoch 48, CIFAR-10 Batch 4:  Loss:   124.9156 | Validation Accuracy: 0.4882
# Epoch 48, CIFAR-10 Batch 5:  Loss:    45.0430 | Validation Accuracy: 0.4784
# Epoch 49, CIFAR-10 Batch 1:  Loss:    69.3928 | Validation Accuracy: 0.4900
# Epoch 49, CIFAR-10 Batch 2:  Loss:   103.2273 | Validation Accuracy: 0.4842
# Epoch 49, CIFAR-10 Batch 3:  Loss:   144.7357 | Validation Accuracy: 0.4926
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4908
# Epoch 49, CIFAR-10 Batch 5:  Loss:   153.2274 | Validation Accuracy: 0.4872
# Epoch 50, CIFAR-10 Batch 1:  Loss:   312.5498 | Validation Accuracy: 0.5008
# Epoch 50, CIFAR-10 Batch 2:  Loss:   101.3578 | Validation Accuracy: 0.4974
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4878
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4832
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4912
# Epoch 51, CIFAR-10 Batch 1:  Loss:    64.8783 | Validation Accuracy: 0.4958
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5008
# Epoch 51, CIFAR-10 Batch 3:  Loss:   169.5266 | Validation Accuracy: 0.4884
# Epoch 51, CIFAR-10 Batch 4:  Loss:   656.8426 | Validation Accuracy: 0.4852
# Epoch 51, CIFAR-10 Batch 5:  Loss:   155.6147 | Validation Accuracy: 0.4908
# Epoch 52, CIFAR-10 Batch 1:  Loss:    62.8877 | Validation Accuracy: 0.4846
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5060
# Epoch 52, CIFAR-10 Batch 3:  Loss:     1.0035 | Validation Accuracy: 0.4940
# Epoch 52, CIFAR-10 Batch 4:  Loss:   547.5402 | Validation Accuracy: 0.4798
# Epoch 52, CIFAR-10 Batch 5:  Loss:   352.1060 | Validation Accuracy: 0.4852
# Epoch 53, CIFAR-10 Batch 1:  Loss:   432.7289 | Validation Accuracy: 0.4906
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5054
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4896
# Epoch 53, CIFAR-10 Batch 4:  Loss:   361.2070 | Validation Accuracy: 0.4788
# Epoch 53, CIFAR-10 Batch 5:  Loss:   452.9117 | Validation Accuracy: 0.4746
# Epoch 54, CIFAR-10 Batch 1:  Loss:    49.5100 | Validation Accuracy: 0.4918
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5070
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5028
# Epoch 54, CIFAR-10 Batch 4:  Loss:   629.5948 | Validation Accuracy: 0.4640
# Epoch 54, CIFAR-10 Batch 5:  Loss:     3.6154 | Validation Accuracy: 0.4932
# Epoch 55, CIFAR-10 Batch 1:  Loss:   120.9590 | Validation Accuracy: 0.4910
# Epoch 55, CIFAR-10 Batch 2:  Loss:   651.7856 | Validation Accuracy: 0.5120
# Epoch 55, CIFAR-10 Batch 3:  Loss:    16.3742 | Validation Accuracy: 0.5032
# Epoch 55, CIFAR-10 Batch 4:  Loss:    73.0375 | Validation Accuracy: 0.4754
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5012
# Epoch 56, CIFAR-10 Batch 1:  Loss:    56.9777 | Validation Accuracy: 0.4864
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5054
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5038
# Epoch 56, CIFAR-10 Batch 4:  Loss:   119.8348 | Validation Accuracy: 0.4858
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4902
# Epoch 57, CIFAR-10 Batch 1:  Loss:   265.0471 | Validation Accuracy: 0.4898
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5112
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4874
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4936
# Epoch 57, CIFAR-10 Batch 5:  Loss:    14.6473 | Validation Accuracy: 0.4954
# Epoch 58, CIFAR-10 Batch 1:  Loss:   122.6311 | Validation Accuracy: 0.4796
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5094
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5062
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4928
# Epoch 58, CIFAR-10 Batch 5:  Loss:   117.6867 | Validation Accuracy: 0.4926
# Epoch 59, CIFAR-10 Batch 1:  Loss:     8.4693 | Validation Accuracy: 0.4838
# Epoch 59, CIFAR-10 Batch 2:  Loss:   361.9709 | Validation Accuracy: 0.5096
# Epoch 59, CIFAR-10 Batch 3:  Loss:    24.7162 | Validation Accuracy: 0.5126
# Epoch 59, CIFAR-10 Batch 4:  Loss:  1030.6469 | Validation Accuracy: 0.5028
# Epoch 59, CIFAR-10 Batch 5:  Loss:    70.7879 | Validation Accuracy: 0.4966
# Epoch 60, CIFAR-10 Batch 1:  Loss:   624.0591 | Validation Accuracy: 0.4928
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5110
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5108
# Epoch 60, CIFAR-10 Batch 4:  Loss:    13.0184 | Validation Accuracy: 0.5016
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5010
# Epoch 61, CIFAR-10 Batch 1:  Loss:   155.6543 | Validation Accuracy: 0.5022
# Epoch 61, CIFAR-10 Batch 2:  Loss:   181.2343 | Validation Accuracy: 0.5096
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5042
# Epoch 61, CIFAR-10 Batch 4:  Loss:   372.7028 | Validation Accuracy: 0.5042
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4988
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4982
# Epoch 62, CIFAR-10 Batch 2:  Loss:   397.5705 | Validation Accuracy: 0.5060
# Epoch 62, CIFAR-10 Batch 3:  Loss:    42.7277 | Validation Accuracy: 0.5026
# Epoch 62, CIFAR-10 Batch 4:  Loss:     1.1703 | Validation Accuracy: 0.5122
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4888
# Epoch 63, CIFAR-10 Batch 1:  Loss:    38.5199 | Validation Accuracy: 0.5080
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4934
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4992
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5162
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4930
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5066
# Epoch 64, CIFAR-10 Batch 2:  Loss:   180.3621 | Validation Accuracy: 0.5016
# Epoch 64, CIFAR-10 Batch 3:  Loss:   462.3645 | Validation Accuracy: 0.4920
# Epoch 64, CIFAR-10 Batch 4:  Loss:    44.6672 | Validation Accuracy: 0.5066
# Epoch 64, CIFAR-10 Batch 5:  Loss:    79.2539 | Validation Accuracy: 0.5000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5058
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4968
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5034
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5090
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5038
# Epoch 66, CIFAR-10 Batch 1:  Loss:   166.1352 | Validation Accuracy: 0.5104
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4980
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4890
# Epoch 66, CIFAR-10 Batch 4:  Loss:     3.8141 | Validation Accuracy: 0.5166
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5022
# Epoch 67, CIFAR-10 Batch 1:  Loss:   250.0014 | Validation Accuracy: 0.5062
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4916
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5102
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5020
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5212
# Epoch 68, CIFAR-10 Batch 1:  Loss:   224.5895 | Validation Accuracy: 0.5066
# Epoch 68, CIFAR-10 Batch 2:  Loss:    18.5906 | Validation Accuracy: 0.5092
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5152
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5238
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5240
# Epoch 69, CIFAR-10 Batch 1:  Loss:    90.0484 | Validation Accuracy: 0.5046
# Epoch 69, CIFAR-10 Batch 2:  Loss:    48.6482 | Validation Accuracy: 0.4992
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5224
# Epoch 69, CIFAR-10 Batch 4:  Loss:   103.0152 | Validation Accuracy: 0.5188
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5220
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5048
# Epoch 70, CIFAR-10 Batch 2:  Loss:   295.3578 | Validation Accuracy: 0.4874
# Epoch 70, CIFAR-10 Batch 3:  Loss:    96.3500 | Validation Accuracy: 0.5140
# Epoch 70, CIFAR-10 Batch 4:  Loss:   192.6024 | Validation Accuracy: 0.5010
# Epoch 70, CIFAR-10 Batch 5:  Loss:   426.3678 | Validation Accuracy: 0.5084
# Epoch 71, CIFAR-10 Batch 1:  Loss:   431.1596 | Validation Accuracy: 0.5006
# Epoch 71, CIFAR-10 Batch 2:  Loss:   101.6051 | Validation Accuracy: 0.5008
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5200
# Epoch 71, CIFAR-10 Batch 4:  Loss:   105.6426 | Validation Accuracy: 0.5022
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5214
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5218
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5204
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5110
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5262
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5242
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5124
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4986
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5124
# Epoch 73, CIFAR-10 Batch 4:  Loss:    20.8539 | Validation Accuracy: 0.5018
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5230
# Epoch 74, CIFAR-10 Batch 1:  Loss:   271.2816 | Validation Accuracy: 0.5216
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5142
# Epoch 74, CIFAR-10 Batch 3:  Loss:    38.4762 | Validation Accuracy: 0.5216
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5054
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5206
# Epoch 75, CIFAR-10 Batch 1:  Loss:   619.6046 | Validation Accuracy: 0.5120
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5140
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5216
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5190
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5176
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5186
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5100
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5266
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5112
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5206
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5250
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5164
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5258
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5194
# Epoch 77, CIFAR-10 Batch 5:  Loss:    30.6363 | Validation Accuracy: 0.5076
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5186
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5136
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5222
# Epoch 78, CIFAR-10 Batch 4:  Loss:   241.7221 | Validation Accuracy: 0.5096
# Epoch 78, CIFAR-10 Batch 5:  Loss:    69.9777 | Validation Accuracy: 0.5206
# Epoch 79, CIFAR-10 Batch 1:  Loss:     4.1803 | Validation Accuracy: 0.5300
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5052
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5296
# Epoch 79, CIFAR-10 Batch 4:  Loss:    56.3807 | Validation Accuracy: 0.5228
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5162
# Epoch 80, CIFAR-10 Batch 1:  Loss:   110.2559 | Validation Accuracy: 0.5150
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5226
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5192
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5130
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5292
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5270
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5024
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5220
# Epoch 81, CIFAR-10 Batch 4:  Loss:   129.6188 | Validation Accuracy: 0.5180
# Epoch 81, CIFAR-10 Batch 5:  Loss:    28.1711 | Validation Accuracy: 0.5208
# Epoch 82, CIFAR-10 Batch 1:  Loss:   113.4769 | Validation Accuracy: 0.5318
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.
# Epoch 107, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5374
# Epoch 108, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5442
# Epoch 108, CIFAR-10 Batch 2:  Loss:     1.3568 | Validation Accuracy: 0.5398
# Epoch 108, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5384
# Epoch 108, CIFAR-10 Batch 4:  Loss:   145.5063 | Validation Accuracy: 0.5280
# Epoch 108, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5370
# Epoch 109, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5396
# Epoch 109, CIFAR-10 Batch 2:  Loss:   109.8270 | Validation Accuracy: 0.5252
# Epoch 109, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 109, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5284
# Epoch 109, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5404
# Epoch 110, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5456
# Epoch 110, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5418
# Epoch 110, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5394
# Epoch 110, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5426
# Epoch 110, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5334
# Epoch 111, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5390
# Epoch 111, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5314
# Epoch 111, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5306
# Epoch 111, CIFAR-10 Batch 4:  Loss:    31.2008 | Validation Accuracy: 0.5378
# Epoch 111, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5392
# Epoch 112, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5434
# Epoch 112, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5288
# Epoch 112, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5380
# Epoch 112, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5344
# Epoch 112, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5380
# Epoch 113, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5366
# Epoch 113, CIFAR-10 Batch 2:  Loss:    14.4883 | Validation Accuracy: 0.5258
# Epoch 113, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5412
# Epoch 113, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5272
# Epoch 113, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5372
# Epoch 114, CIFAR-10 Batch 1:  Loss:    53.0662 | Validation Accuracy: 0.5366
# Epoch 114, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5364
# Epoch 114, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5474
# Epoch 114, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5458
# Epoch 114, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5402
# Epoch 115, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5480
# Epoch 115, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5446
# Epoch 115, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5404
# Epoch 115, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5500
# Epoch 115, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5390
# Epoch 116, CIFAR-10 Batch 1:  Loss:    29.8639 | Validation Accuracy: 0.5492
# Epoch 116, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5360
# Epoch 116, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5412
# Epoch 116, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5398
# Epoch 116, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5426
# Epoch 117, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5418
# Epoch 117, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5368
# Epoch 117, CIFAR-10 Batch 3:  Loss:    28.8549 | Validation Accuracy: 0.5404
# Epoch 117, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5408
# Epoch 117, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5366
# Epoch 118, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5320
# Epoch 118, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5520
# Epoch 118, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 118, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5376
# Epoch 118, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5396
# Epoch 119, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5276
# Epoch 119, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5400
# Epoch 119, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5522
# Epoch 119, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5452
# Epoch 119, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5390
# Epoch 120, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5344
# Epoch 120, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5338
# Epoch 120, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5508
# Epoch 120, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5432
# Epoch 120, CIFAR-10 Batch 5:  Loss:    72.3689 | Validation Accuracy: 0.5462
# Epoch 121, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5386
# Epoch 121, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5558
# Epoch 121, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5452
# Epoch 121, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5522
# Epoch 121, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5430
# Epoch 122, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5422
# Epoch 122, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5404
# Epoch 122, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 122, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5410
# Epoch 122, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5396
# Epoch 123, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5246
# Epoch 123, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5324
# Epoch 123, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5376
# Epoch 123, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5388
# Epoch 123, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5340
# Epoch 124, CIFAR-10 Batch 1:  Loss:    23.4283 | Validation Accuracy: 0.5288
# Epoch 124, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5348
# Epoch 124, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5318
# Epoch 124, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5312
# Epoch 124, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5338
# Epoch 125, CIFAR-10 Batch 1:  Loss:    58.1225 | Validation Accuracy: 0.5276
# Epoch 125, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 125, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 125, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5416
# Epoch 125, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5418
# Epoch 126, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5402
# Epoch 126, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5434
# Epoch 126, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5396
# ...
# Epoch 459, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5798
# Epoch 459, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5882
# Epoch 460, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5892
# Epoch 460, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5856
# Epoch 460, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5824
# Epoch 460, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5900
# Epoch 460, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5958
# Epoch 461, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5932
# Epoch 461, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5974
# Epoch 461, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5866
# Epoch 461, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5982
# Epoch 461, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5948
# Epoch 462, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5896
# Epoch 462, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5888
# Epoch 462, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5952
# Epoch 462, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5938
# Epoch 462, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5874
# Epoch 463, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5836
# Epoch 463, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5958
# Epoch 463, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5796
# Epoch 463, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5884
# Epoch 463, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5972
# Epoch 464, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5930
# Epoch 464, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5796
# Epoch 464, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5890
# Epoch 464, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5888
# Epoch 464, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5912
# Epoch 465, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5808
# Epoch 465, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6030
# Epoch 465, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5960
# Epoch 465, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5768
# Epoch 465, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5832
# Epoch 466, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5872
# Epoch 466, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5880
# Epoch 466, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5882
# Epoch 466, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5772
# Epoch 466, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5884
# Epoch 467, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5926
# Epoch 467, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5878
# Epoch 467, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5914
# Epoch 467, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5900
# Epoch 467, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5912
# Epoch 468, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5978
# Epoch 468, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5930
# Epoch 468, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5920
# Epoch 468, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5988
# Epoch 468, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5890
# Epoch 469, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5968
# Epoch 469, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5932
# Epoch 469, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5758
# Epoch 469, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5778
# Epoch 469, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5824
# Epoch 470, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5904
# Epoch 470, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6014
# Epoch 470, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5962
# Epoch 470, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.6034
# Epoch 470, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5988
# Epoch 471, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6016
# Epoch 471, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5986
# Epoch 471, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5920
# Epoch 471, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5990
# Epoch 471, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5838
# Epoch 472, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5918
# Epoch 472, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5834
# Epoch 472, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5874
# Epoch 472, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5892
# Epoch 472, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5920
# Epoch 473, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5872
# Epoch 473, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5838
# Epoch 473, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5806
# Epoch 473, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5786
# Epoch 473, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5860
# Epoch 474, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5874
# Epoch 474, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5992
# Epoch 474, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5976
# Epoch 474, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5928
# Epoch 474, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5906
# Epoch 475, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5840
# Epoch 475, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5862
# Epoch 475, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5842
# Epoch 475, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5836
# Epoch 475, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5886
# Epoch 476, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5860
# Epoch 476, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5830
# Epoch 476, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5872
# Epoch 476, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5842
# Epoch 476, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5806
# Epoch 477, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5958
# Epoch 477, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5740
# Epoch 477, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5954
# Epoch 477, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5894
# Epoch 477, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5820
# Epoch 478, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5914
# Epoch 478, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5936
# Epoch 478, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5910
# Epoch 478, CIFAR-10 Batch 4:  Loss:    69.2564 | Validation Accuracy: 0.5974
# Epoch 478, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6004
# Epoch 479, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5982
# Epoch 479, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5924
# Epoch 479, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5956
# Epoch 479, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5946
# Epoch 479, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5938
# Epoch 480, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5944
# Epoch 480, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5872
# Epoch 480, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5836
# Epoch 480, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5934
# Epoch 480, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5960
# Epoch 481, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5848
# Epoch 481, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5854
# Epoch 481, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5946
# Epoch 481, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5896
# Epoch 481, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6028
# Epoch 482, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5900
# Epoch 482, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5962
# Epoch 482, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5916
# Epoch 482, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5780
# Epoch 482, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5932
# Epoch 483, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5922
# Epoch 483, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5914
# Epoch 483, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5904
# Epoch 483, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5956
# Epoch 483, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5834
# Epoch 484, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5894
# Epoch 484, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5936
# Epoch 484, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5856
# Epoch 484, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5918
# Epoch 484, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5788
# Epoch 485, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5990
# Epoch 485, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5870
# Epoch 485, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5826
# Epoch 485, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5902
# Epoch 485, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5896
# Epoch 486, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5918
# Epoch 486, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5918
# Epoch 486, CIFAR-10 Batch 3:  Loss:    52.2941 | Validation Accuracy: 0.5878
# Epoch 486, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5920
# Epoch 486, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5994
# Epoch 487, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6006
# Epoch 487, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5960
# Epoch 487, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5882
# Epoch 487, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5976
# Epoch 487, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5912
# Epoch 488, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5906
# Epoch 488, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5904
# Epoch 488, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5890
# Epoch 488, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5926
# Epoch 488, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5912
# Epoch 489, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5810
# Epoch 489, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6050
# Epoch 489, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6000
# Epoch 489, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5850
# Epoch 489, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5904
# Epoch 490, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5936
# Epoch 490, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5808
# Epoch 490, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5946
# Epoch 490, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5928
# Epoch 490, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5986
# Epoch 491, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5848
# Epoch 491, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5878
# Epoch 491, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5882
# Epoch 491, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5914
# Epoch 491, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5918
# Epoch 492, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5880
# Epoch 492, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5954
# Epoch 492, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5920
# Epoch 492, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5952
# Epoch 492, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6012
# Epoch 493, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5936
# Epoch 493, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5948
# Epoch 493, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5998
# Epoch 493, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5952
# Epoch 493, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5924
# Epoch 494, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5964
# Epoch 494, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5910
# Epoch 494, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6052
# Epoch 494, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5922
# Epoch 494, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6010
# Epoch 495, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5788
# Epoch 495, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5954
# Epoch 495, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5934
# Epoch 495, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5942
# Epoch 495, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5866
# Epoch 496, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5938
# Epoch 496, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5976
# Epoch 496, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5974
# Epoch 496, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5986
# Epoch 496, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6030
# Epoch 497, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5878
# Epoch 497, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5874
# Epoch 497, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5924
# Epoch 497, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5966
# Epoch 497, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5910
# Epoch 498, CIFAR-10 Batch 1:  Loss:    12.3488 | Validation Accuracy: 0.6028
# Epoch 498, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5950
# Epoch 498, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5914
# Epoch 498, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.6030
# Epoch 498, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5880
# Epoch 499, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6024
# Epoch 499, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5854
# Epoch 499, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5816
# Epoch 499, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.6016
# Epoch 499, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5896
# Epoch 500, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5884
# Epoch 500, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6010
# Epoch 500, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5986
# Epoch 500, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5904
# Epoch 500, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5918

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6001780063291139

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
